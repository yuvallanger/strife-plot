# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import h5py
from glob import glob
from matplotlib import animation

# %%
filename_template_ccost_10 = 'data/avigdor-utcepoch-*-sth-{sth}-cth-{cth}-ccost-10.json*.h5'
filename_template_ccost_30 = 'data/avigdor-utcepoch-*-sth-{sth}-cth-{cth}-ccost-30.json*.h5'
filename_template_diffusion_02 = 'data/avigdor-utcepoch-*-sth-{sth}-cth-{cth}-ccost-36-D-0.2.json-*.h5'
filename_template_diffusion_04 = 'data/avigdor-utcepoch-*-sth-{sth}-cth-{cth}-ccost-36-D-0.4.json-*.h5'

# %%
def get_filename_list(filename_template):
    return [[
        glob(filename_template.format(
            sth=row_i,
            cth=col_i,
        ))[0]
    for col_i in range(10)]
    for row_i in range(10)]

def open_h5py_files(filename_list_list):
    return [
        [h5py.File(filename) for filename in filename_list]
    for filename_list in filename_list_list]

ff_list_ccost_10 = open_h5py_files(get_filename_list(filename_template_ccost_10))
ff_list_ccost_30 = open_h5py_files(get_filename_list(filename_template_ccost_30))
ff_list_diffusion_02 = open_h5py_files(get_filename_list(filename_template_diffusion_02))
ff_list_diffusion_04 = open_h5py_files(get_filename_list(filename_template_diffusion_04))

# %%
def beaut(fig, axes):
    for row_i, axes_row in enumerate(axes):
        for col_i, ax in enumerate(axes_row):
            ax.set_xticks([])
            ax.set_yticks([])
                
            if col_i == 0:
                ax.set_ylabel(str(row_i))
                
            if row_i == 9:
                ax.set_xlabel(str(col_i))
    
    plt.figtext(
        0.5,
        0,
        "public goods effect threshold",
        figure=fig,
        fontsize=17,
        horizontalalignment='center',
        verticalalignment='top',
    )
    plt.figtext(
        0,
        0.5,
        "quorum sensing threshold",
        figure=fig,
        fontsize=17,
        horizontalalignment='right',
        verticalalignment='center',
        rotation=90,
    )
    fig.tight_layout()

# %%
def make_plots(data, plotter):
    fig, axes = plt.subplots(
        figsize=(13,13),
        nrows=10,
        ncols=10,
    )
    
    for row_i in range(10):
        for col_i in range(10):
                plotter(axes, data, row_i, col_i)
                
    beaut(fig, axes)
    
    return fig, axes

# %%
def get_simulation_freqs_data_list(ff_list_list):
    return [[
        ff['/DataSamples/Frequencies/Data'][:, 4:]
    for ff in ff_list]
    for ff_list in ff_list_list]

# %%
def freqs_plotter(axes, freqs_data, sth, cth):
    for strain_i in range(4):
        axes[sth][cth].plot(
            freqs_data[sth][cth][:, strain_i],
            label=str(strain_i),
        )

# %%
def make_freqs_plots(ff_list_list):
    data = get_simulation_freqs_data_list(ff_list_list)
    fig, axes = make_plots(data, freqs_plotter)
    
    return fig, axes

# %%
make_freqs_plots(ff_list_ccost_10);

# %%
make_freqs_plots(ff_list_ccost_30);

# %%
make_freqs_plots(ff_list_diffusion_02);

# %%
make_freqs_plots(ff_list_diffusion_04);

# %%
def make_anim(ff):
    fig, axes = plt.subplots(
        figsize=(13,13),
        nrows=10,
        ncols=10,
    )
    
    im_list_list = [[
        ax.imshow(ff['/DataSamples/Snapshots/Data'][1])
        for ff, ax in zip(ff_row, axes_row)]
        for ff_row, axes_row in zip(ff, axes)]

    beaut(fig, axes)

    def animate_func(generation_i):
        for im_list, ff_list in zip(im_list_list, ff_list_ccost_10):
            for im, ff in zip(im_list, ff_list):
                im.set_data(ff['/DataSamples/Snapshots/Data'][generation_i])
        return im_list_list
    
    return animation.FuncAnimation(
        fig,
        animate_func,
        arange(200),
    )

# %%
make_anim(ff_list_ccost_10).save('ccost-10.mp4')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-6757d30df573> in <module>()
# ----> 1 make_anim(ff_list_ccost_10).save('ccost-10.mp4')
#
# /home/yankel/.pythonz/venvs/ipython/local/lib/python2.7/site-packages/matplotlib/animation.pyc in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#     715                 for anim, d in zip(all_anim, data):
#     716                     #TODO: Need to see if turning off blit is really necessary
# --> 717                     anim._draw_next_frame(d, blit=False)
#     718                 writer.grab_frame(**savefig_kwargs)
#     719
#
# /home/yankel/.pythonz/venvs/ipython/local/lib/python2.7/site-packages/matplotlib/animation.pyc in _draw_next_frame(self, framedata, blit)
#     752         # post- draw, as well as the drawing of the frame itself.
#     753         self._pre_draw(framedata, blit)
# --> 754         self._draw_frame(framedata)
#     755         self._post_draw(framedata, blit)
#     756
#
# /home/yankel/.pythonz/venvs/ipython/local/lib/python2.7/site-packages/matplotlib/animation.pyc in _draw_frame(self, framedata)
#    1047         # Call the func with framedata and args. If blitting is desired,
#    1048         # func needs to return a sequence of any artists that were modified.
# -> 1049         self._drawn_artists = self._func(framedata, *self._args)
#
# <ipython-input-14-0ca85b19db09> in animate_func(generation_i)
#      16         for im_list, ff_list in zip(im_list_list, ff_list_ccost_10):
#      17             for im, ff in zip(im_list, ff_list):
# ---> 18                 im.set_data(ff['/DataSamples/Snapshots/Data'][generation_i])
#      19         return im_list_list
#      20
#
# /home/yankel/.pythonz/venvs/ipython/local/lib/python2.7/site-packages/h5py/_hl/dataset.pyc in __getitem__(self, args)
#     443         mspace = h5s.create_simple(mshape)
#     444         fspace = selection._id
# --> 445         self.id.read(mspace, fspace, arr, mtype)
#     446
#     447         # Patch up the output for NumPy
#
# KeyboardInterrupt:

# %%
make_anim(ff_list_ccost_30).save('ccost-30.mp4')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-4185010f086f> in <module>()
# ----> 1 make_anim(ff_list_ccost_30).save('ccost-30.mp4')
#
# /home/yankel/.pythonz/venvs/ipython/local/lib/python2.7/site-packages/matplotlib/animation.pyc in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#     715                 for anim, d in zip(all_anim, data):
#     716                     #TODO: Need to see if turning off blit is really necessary
# --> 717                     anim._draw_next_frame(d, blit=False)
#     718                 writer.grab_frame(**savefig_kwargs)
#     719
#
# /home/yankel/.pythonz/venvs/ipython/local/lib/python2.7/site-packages/matplotlib/animation.pyc in _draw_next_frame(self, framedata, blit)
#     752         # post- draw, as well as the drawing of the frame itself.
#     753         self._pre_draw(framedata, blit)
# --> 754         self._draw_frame(framedata)
#     755         self._post_draw(framedata, blit)
#     756
#
# /home/yankel/.pythonz/venvs/ipython/local/lib/python2.7/site-packages/matplotlib/animation.pyc in _draw_frame(self, framedata)
#    1047         # Call the func with framedata and args. If blitting is desired,
#    1048         # func needs to return a sequence of any artists that were modified.
# -> 1049         self._drawn_artists = self._func(framedata, *self._args)
#
# <ipython-input-14-0ca85b19db09> in animate_func(generation_i)
#      16         for im_list, ff_list in zip(im_list_list, ff_list_ccost_10):
#      17             for im, ff in zip(im_list, ff_list):
# ---> 18                 im.set_data(ff['/DataSamples/Snapshots/Data'][generation_i])
#      19         return im_list_list
#      20
#
# /home/yankel/.pythonz/venvs/ipython/local/lib/python2.7/site-packages/h5py/_hl/dataset.pyc in __getitem__(self, args)
#     443         mspace = h5s.create_simple(mshape)
#     444         fspace = selection._id
# --> 445         self.id.read(mspace, fspace, arr, mtype)
#     446
#     447         # Patch up the output for NumPy
#
# KeyboardInterrupt:

# %%
make_anim(ff_list_diffusion_02).save('diffusion-02.mp4')

# %%
make_anim(ff_list_diffusion_04).save('diffusion-04.mp4')
