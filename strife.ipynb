# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import h5py
from glob import glob

# %%
filename_template_ccost_10 = 'data/avigdor-utcepoch-*-sth-{sth}-cth-{cth}-ccost-10.json*.h5'
filename_template_ccost_30 = 'data/avigdor-utcepoch-*-sth-{sth}-cth-{cth}-ccost-30.json*.h5'
filename_template_diffusion_02 = 'data/avigdor-utcepoch-*-sth-{sth}-cth-{cth}-ccost-36-D-0.2.json-*.h5'
filename_template_diffusion_04 = 'data/avigdor-utcepoch-*-sth-{sth}-cth-{cth}-ccost-36-D-0.4.json-*.h5'

# %%
def get_filename_list(filename_template):
    return [[
        glob(filename_template.format(
            sth=row_i,
            cth=col_i,
        ))[0]
    for col_i in range(10)]
    for row_i in range(10)]

filename_list_ccost_10 = get_filename_list(filename_template_ccost_10)
filename_list_ccost_30 = get_filename_list(filename_template_ccost_30)
filename_list_diffusion_02 = get_filename_list(filename_template_diffusion_02)
filename_list_diffusion_04 = get_filename_list(filename_template_diffusion_04)

# %%
def beaut(fig, axes):
    for row_i, axes_row in enumerate(axes):
        for col_i, ax in enumerate(axes_row):
            ax.set_xticks([])
            ax.set_yticks([])
                
            if col_i == 0:
                ax.set_ylabel(str(row_i))
                
            if row_i == 9:
                ax.set_xlabel(str(col_i))
    
    plt.figtext(
        0.5,
        0,
        "public goods effect threshold",
        figure=fig,
        fontsize=17,
        horizontalalignment='center',
        verticalalignment='top',
    )
    plt.figtext(
        0,
        0.5,
        "quorum sensing threshold",
        figure=fig,
        fontsize=17,
        horizontalalignment='right',
        verticalalignment='center',
        rotation=90,
    )
    fig.tight_layout()

# %%
def make_plots(data, plotter):
    fig, axes = plt.subplots(
        figsize=(10,10),
        dpi=100,
        nrows=10,
        ncols=10,
    )
    
    for row_i in range(10):
        for col_i in range(10):
                plotter(axes, data, row_i, col_i)
                
    beaut(fig, axes)
    
    return fig, axes

# %%
def get_simulation_freqs_data_list(filename_list):
    return [[
        h5py.File(filename)['DataSamples']['Frequencies']['Data'][:, 4:]
    for filename in row]
    for row in filename_list]

# %%
def freqs_plotter(axes, freqs_data, sth, cth):
    for strain_i in range(4):
        axes[sth][cth].plot(
            freqs_data[sth][cth][:, strain_i],
            label=str(strain_i),
        )

# %%
def make_freqs_plots(filename_list):
    data = get_simulation_freqs_data_list(filename_list)
    fig, axes = make_plots(data, freqs_plotter)
    
    return fig, axes

# %%
make_freqs_plots(filename_list_ccost_10);

# %%
make_freqs_plots(filename_list_ccost_30);

# %%
make_freqs_plots(filename_list_diffusion_02);

# %%
make_freqs_plots(filename_list_diffusion_04);
